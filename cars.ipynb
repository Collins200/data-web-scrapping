# %%
# site url
site="https://www.cars.com/shopping/"

# %%
# import libraries
from bs4 import BeautifulSoup as Bs
import requests
import pandas

# %%
# load the page
r=requests.get(site)

# %%
# use beautifulsoup to load the page content
soup=Bs(r.content)

# %%
# use prettify function to parse over the html tags
content=soup.prettify()

# %%
# display the page source content
print(content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Used Cars for Sale Online Near Me | Cars.com
#   </title>
#   <meta content="Browse cars for sale, shop the best deals near you, find current loan rates and read FAQs about financing and warranties at Cars.com." name="description"/>
#   <link href="https://beta.cars.com/shopping/" rel="canonical"/>
#   <meta content="Cars.com" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Used Cars for Sale Online Near Me | Cars.com" property="og:title"/>
#   <meta content="https://beta.cars.com/shopping/" property="og:url"/>
#   <meta content="Browse cars for sale, shop the best deals near you, find current loan rates and read FAQs about financing and warranties at Cars.com." property="og:description"/>
# ...

# %%
# find all the div tags with the class browse-makes
cars_div=soup.find_all('div',class_='browse-makes')
print(len(cars_div))
print(type(cars_div))
# Out:
# 0
# <class 'bs4.element.ResultSet'>

# %%
# output the content of the div tags
print(cars_div)
# Out:
# []

# %%
# display the section of the div that contains the cars body section
cars=cars_div[0]
print(cars)

# %%
cars.div

# %%
# find the title of the div element
cars.h3

# %%
# display the title of the div element
title=cars.h3.get_text()
print(title)

# %%
cars.div.li

# %%
cars.div.li.text

# %%
# find all the elements under the 'li' tags
cars.div.findAll('li')

# %%
# find all 'li' elements with class 'col-dt-4'
ordered_li=cars.div.findAll('li',class_='col-dt-4')

# %%
ordered_li

# %%
# print the lenght of list
print(len(ordered_li))

# %%
# access the first element
ordered_li[0]

# %%
# find the text of the 'a' tag of the first element in the list
ordered_li[1].get_text()

# %%
# access the car_brands and append them to empty list named cars_brands
car_brands=[]
for element in ordered_li:
    car_brand=element.get_text()
    car_brands.append(car_brand)

# %%
# print the car_brands names
car_brands

# %%
# create a list of cars link
links=[]
for element in ordered_li:
    car_brand_link=element.findAll('a')
    links.append(car_brand_link)

# %%
# output the cars links from the created list above...
links

# %%
# access only the 'a' tags from the links
brand_link=cars.div.findAll('a')

# %%
links[0]

# %%
brand_linkss=cars.div.findAll('a')
f'https://www.cars.com{brand_link[0].attrs["href"]}'

# %%
# output the 'a' tags of all the cars
brand_link

# %%
brand_link[0].attrs

# %%
brand_link[0].attrs['href']

# %%
print(len(brand_link))

# %%
# create a list of 'href' attributes of all cars
brand_links=[]
for n in range(0,len(brand_link)):
        car_link=brand_link[n].attrs['href']
        brand_links.append(car_link)

# %%
# output the "href tags of all cars"
brand_links

# %%
# website_link=https://www.cars.com
# web_link=' https://www.cars.com'.join(["{}"]*59).format(*brand_links)

# %%
# web_link

# %%
s=['/job/search/','/job/lists']
base_url='https://python.com'
s=[base_url+s[0],base_url+s[1]]
print(s)

# %%
# concatinate the base url with the 'href' tags and append the list to an empty list
w_links=[]
base_url='https://www.cars.com'
for n in range(0,59):
        c_link=base_url+brand_links[n]
        w_links.append(c_link)

# %%
# output the empty list
w_links

# %%
# output the individual ement in the list
for link in w_links:
    print(link)

# %%
r1=requests.get('https://www.cars.com/research/sedan/')

# %%
soup1=Bs(r1.content)

# %%
content1=soup1.prettify()
# print(content1)

# %%
soup1.find_all('div',class_='mlp-container')
# Out:
# [<div class="mlp-container">
#  <div class="mlp-listings-container" ng-class="{ 'listview': ctrl.listview, 'compare-active': ctrl.compareActive }" ng-controller="carsModellistingCategoryListingsController as ctrl">
#  <div class="listingCard" ng-class="{ 'added-to-compare' : cardCtrl.addedToCompare }" ng-controller="carsModellistingCategoryListingCard as cardCtrl" ng-init="cardCtrl.init('bmw-740-2021')" style="order: 0">
#  <a cars-tracking-omniture-standard="md-thumb" class="card-image-link" data-linkname="md-thumb" href="/research/bmw-740-2021/">
#  <span class="bestbet-flag">MOST POPULAR</span>
#  <div class="card-image-container img-default">
#  <img alt="2021 BMW 740 4dr RWD Sedan" class="card-image" loading="lazy" src="https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png"/>
#  </div>
#  </a>
#  <div class="card-details">
#  <a cars-tracking-omniture-standard="md-ymmt" data-linkname="md-ymmt" href="/research/bmw-740-2021/">
# ...

# %%
images=soup1.findAll('img')

# %%
print(len(images))
# Out:
# 101

# %%
imag=[]
for img in images:
    print(img['src'])
#     print(img.attrs['src'])

    imag.append(img.attrs['src'])
# Out:
# /cldstatic/header/0.2.3/logo.png
# https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png
# https://www.cstatic-images.com/car-pictures/main/usd00bmc012a021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10bmc832a021001.png
# https://www.cstatic-images.com/stock/400x500/1563823719672.png
# https://www.cstatic-images.com/car-pictures/main/usc90mbccc1a021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10mbcay2a021001.png
# https://www.cstatic-images.com/car-pictures/main/usd00prc201b021001.png
# https://www.cstatic-images.com/car-pictures/main/USC50RRC071A021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10suc042b021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10voc371b021001.png
# https://www.cstatic-images.com/car-pictures/main/usc90acc141c021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10acc181d021001.png
# https://www.cstatic-images.com/car-pictures/main/usd00auc016a021001.png
# ...

# %%
for img in images:
    name=img['alt']
    link=img['src']
    if link[0]=='h':
        print(name,link)
# Out:
# 2021 BMW 740 4dr RWD Sedan https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png
# 2021 BMW 750 4dr AWD Sedan https://www.cstatic-images.com/car-pictures/main/usd00bmc012a021001.png
# 2021 BMW 530e 4dr RWD Sedan https://www.cstatic-images.com/car-pictures/main/usd10bmc832a021001.png
# 2021 Bentley Flying Spur https://www.cstatic-images.com/stock/400x500/1563823719672.png
# 2021 Mercedes-Benz A 220 4dr FWD Sedan https://www.cstatic-images.com/car-pictures/main/usc90mbccc1a021001.png
# 2021 Mercedes-Benz AMG E 63 4dr AWD 4MATIC+ Sedan https://www.cstatic-images.com/car-pictures/main/usd10mbcay2a021001.png
# 2021 Porsche Taycan 4dr AWD Sedan https://www.cstatic-images.com/car-pictures/main/usd00prc201b021001.png
# 2021 Rolls-Royce Ghost https://www.cstatic-images.com/car-pictures/main/USC50RRC071A021001.png
# 2021 Subaru Impreza 4dr AWD Sedan https://www.cstatic-images.com/car-pictures/main/usd10suc042b021001.png
# ...

# %%
for img in images:
    name=img['alt']
    link=img['src']
    price=fi
    if link[0]=='h':
        with open(name +'.png','wb') as f:
            im=requests.get(link)
            f.write(im.content)

# %%
# soup1.find_all('h2', class_='listing-row__title')
soup1.find("div", {"id": "srp-listing-rows-container"})

# %%
# with open(name.replace('','-').replace('/','')+'.jpg','wb') as f:
with open(name +'.png','wb') as f:
    
    im=requests.get(link)
    f.write(im.content)
#     print('Writing...',name)

# %%
# for img in images:
#     if (img.attrs['src'])=
#     print(img.attrs['src'])

# %%
import io

# from PIL import Image
# import requests 
# from io import BytesIO

# for img in images:
#     url=img.attrs['src']
#     image_file_path='/home/collins/Desktop/CORONA PERIOD/IMAGES/'
#     def download_image(url, image_file_path):
#         r = requests.get(url, timeout=4.0)
#         if r.status_code != requests.codes.ok:
#             assert False, 'Status code error: {}.'.format(r.status_code)
#         with Image.open(io.BytesIO(r.content)) as im:
#             im.save(image_file_path)
        
#         print('Image downloaded from url: {} and saved to: {}.'.format(url, image_file_path))
        
#         download_image(url,image_file_path)

# %%
# import io
# from io import BytesIO
# from PIL import Image
# import requests 


# for img in images:
#     import io
#     from PIL import Image
#     import requests 
#     url=img.attrs['src']
#     image_file_path='/home/collins/Desktop/CORONA PERIOD/IMAGES/'
#     Image.open(io.BytesIO(request.urlopen(url).read())).save(image_file_path)

# %%
# !pip install pillow

# %%
# import io
# from PIL import Image
# import requests

# def download_image(url, file_name):
#     r=requests.get(url)
#     im=Image.open(BytesIO(r.content))
#     im.save(file_name)
    
# if __name__=="__main__":
    
#     img_url="https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png"
#     file="/home/collins/Desktop/CORONA PERIOD/IMAGES/sedan.png"
#     download_image(img_url,file)

# %%
# import io
# from PIL import Image
# import requests

# def download_image(url, file_name):
#     r=requests.get(url)
#     im=Image.open(BytesIO(r.content))
#     im.save(file_name)
    
# if __name__=="__main__":
    
#     file="/home/collins/Desktop/CORONA PERIOD/IMAGES/sedan.png"
# for img in imag:
#     img_url=img
    
    
#     download_image(img_url,file)

# %%
cleaned_img_url=[]
for img in imag:
    img_url=list(filter(lambda x: x.startswith('h'), imag))
    print(img_url)
#     cleaned_img_url.append(img_url)
# Out:
# ['https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00bmc012a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10bmc832a021001.png', 'https://www.cstatic-images.com/stock/400x500/1563823719672.png', 'https://www.cstatic-images.com/car-pictures/main/usc90mbccc1a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10mbcay2a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00prc201b021001.png', 'https://www.cstatic-images.com/car-pictures/main/USC50RRC071A021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10suc042b021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10voc371b021001.png', 'https://www.cstatic-images.com/car-pictures/main/usc90acc141c021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10acc181d021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00auc016a021001.png', 'https://www.cstatic-images.com
# ...

# %%
for imagee in img_url:
    print(imagee)
# Out:
# https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png
# https://www.cstatic-images.com/car-pictures/main/usd00bmc012a021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10bmc832a021001.png
# https://www.cstatic-images.com/stock/400x500/1563823719672.png
# https://www.cstatic-images.com/car-pictures/main/usc90mbccc1a021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10mbcay2a021001.png
# https://www.cstatic-images.com/car-pictures/main/usd00prc201b021001.png
# https://www.cstatic-images.com/car-pictures/main/USC50RRC071A021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10suc042b021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10voc371b021001.png
# https://www.cstatic-images.com/car-pictures/main/usc90acc141c021001.png
# https://www.cstatic-images.com/car-pictures/main/usd10acc181d021001.png
# https://www.cstatic-images.com/car-pictures/main/usd00auc016a021001.png
# ...

# %%
for img in cleaned_img_url:
    print(img[1:])
# Out:
# ['https://www.cstatic-images.com/car-pictures/main/usd00bmc012a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10bmc832a021001.png', 'https://www.cstatic-images.com/stock/400x500/1563823719672.png', 'https://www.cstatic-images.com/car-pictures/main/usc90mbccc1a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10mbcay2a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00prc201b021001.png', 'https://www.cstatic-images.com/car-pictures/main/USC50RRC071A021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10suc042b021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10voc371b021001.png', 'https://www.cstatic-images.com/car-pictures/main/usc90acc141c021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10acc181d021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00auc016a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usc90auc021a021001.png', 'https://www.cstatic-images.com
# ...

# %%
for img in cleaned_img_url:
    img_url=img
    print(img_url)
# Out:
# ['https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00bmc012a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10bmc832a021001.png', 'https://www.cstatic-images.com/stock/400x500/1563823719672.png', 'https://www.cstatic-images.com/car-pictures/main/usc90mbccc1a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10mbcay2a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00prc201b021001.png', 'https://www.cstatic-images.com/car-pictures/main/USC50RRC071A021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10suc042b021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10voc371b021001.png', 'https://www.cstatic-images.com/car-pictures/main/usc90acc141c021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10acc181d021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00auc016a021001.png', 'https://www.cstatic-images.com
# ...

# %%
for img in cleaned_img_url:
    img_url=img
    im_url=("[{0}]".format(', '.join(map(str, img_url))))

# %%
# import pandas as pd
import pandas as pd
  
# Calling DataFrame constructor on list
df = pd.DataFrame(imag)
df
# Out:
#                                                      0
# 0                     /cldstatic/header/0.2.3/logo.png
# 1    https://www.cstatic-images.com/car-pictures/ma...
# 2    https://www.cstatic-images.com/car-pictures/ma...
# 3    https://www.cstatic-images.com/car-pictures/ma...
# 4    https://www.cstatic-images.com/stock/400x500/1...
# ..                                                 ...
# 96   https://www.cstatic-images.com/car-pictures/ma...
# 97   https://www.cstatic-images.com/car-pictures/ma...
# 98   https://www.cstatic-images.com/car-pictures/ma...
# 99   https://www.cstatic-images.com/car-pictures/ma...
# 100  https://www.cstatic-images.com/car-pictures/ma...
#
# [101 rows x 1 columns]

# %%
print(cleaned_img_url)
# Out:
# [['https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00bmc012a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10bmc832a021001.png', 'https://www.cstatic-images.com/stock/400x500/1563823719672.png', 'https://www.cstatic-images.com/car-pictures/main/usc90mbccc1a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10mbcay2a021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00prc201b021001.png', 'https://www.cstatic-images.com/car-pictures/main/USC50RRC071A021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10suc042b021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10voc371b021001.png', 'https://www.cstatic-images.com/car-pictures/main/usc90acc141c021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd10acc181d021001.png', 'https://www.cstatic-images.com/car-pictures/main/usd00auc016a021001.png', 'https://www.cstatic-images.co
# ...

# %%
df[1:]
# Out:
#                                                      0
# 1    https://www.cstatic-images.com/car-pictures/ma...
# 2    https://www.cstatic-images.com/car-pictures/ma...
# 3    https://www.cstatic-images.com/car-pictures/ma...
# 4    https://www.cstatic-images.com/stock/400x500/1...
# 5    https://www.cstatic-images.com/car-pictures/ma...
# ..                                                 ...
# 96   https://www.cstatic-images.com/car-pictures/ma...
# 97   https://www.cstatic-images.com/car-pictures/ma...
# 98   https://www.cstatic-images.com/car-pictures/ma...
# 99   https://www.cstatic-images.com/car-pictures/ma...
# 100  https://www.cstatic-images.com/car-pictures/ma...
#
# [100 rows x 1 columns]

# %%
link=df[1:]

# %%
lis_values=link.values.tolist()

# %%
print(lis_values)
# Out:
# [['https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png'], ['https://www.cstatic-images.com/car-pictures/main/usd00bmc012a021001.png'], ['https://www.cstatic-images.com/car-pictures/main/usd10bmc832a021001.png'], ['https://www.cstatic-images.com/stock/400x500/1563823719672.png'], ['https://www.cstatic-images.com/car-pictures/main/usc90mbccc1a021001.png'], ['https://www.cstatic-images.com/car-pictures/main/usd10mbcay2a021001.png'], ['https://www.cstatic-images.com/car-pictures/main/usd00prc201b021001.png'], ['https://www.cstatic-images.com/car-pictures/main/USC50RRC071A021001.png'], ['https://www.cstatic-images.com/car-pictures/main/usd10suc042b021001.png'], ['https://www.cstatic-images.com/car-pictures/main/usd10voc371b021001.png'], ['https://www.cstatic-images.com/car-pictures/main/usc90acc141c021001.png'], ['https://www.cstatic-images.com/car-pictures/main/usd10acc181d021001.png'], ['https://www.cstatic-images.com/car-pictures/main/usd00auc016a021001.png'], ['htt
# ...

# %%
for img in lis_values:
    print(img)
# Out:
# ['https://www.cstatic-images.com/car-pictures/main/usd00bmc081a021001.png']
# ['https://www.cstatic-images.com/car-pictures/main/usd00bmc012a021001.png']
# ['https://www.cstatic-images.com/car-pictures/main/usd10bmc832a021001.png']
# ['https://www.cstatic-images.com/stock/400x500/1563823719672.png']
# ['https://www.cstatic-images.com/car-pictures/main/usc90mbccc1a021001.png']
# ['https://www.cstatic-images.com/car-pictures/main/usd10mbcay2a021001.png']
# ['https://www.cstatic-images.com/car-pictures/main/usd00prc201b021001.png']
# ['https://www.cstatic-images.com/car-pictures/main/USC50RRC071A021001.png']
# ['https://www.cstatic-images.com/car-pictures/main/usd10suc042b021001.png']
# ['https://www.cstatic-images.com/car-pictures/main/usd10voc371b021001.png']
# ['https://www.cstatic-images.com/car-pictures/main/usc90acc141c021001.png']
# ['https://www.cstatic-images.com/car-pictures/main/usd10acc181d021001.png']
# ...
